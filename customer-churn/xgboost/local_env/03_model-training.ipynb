# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

from xgboost import XGBClassifier
# Out:
# /home/subratho/.local/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1. Set Default Data Repo and load data

# %%
X = pd.read_csv('X_val.csv')
y = pd.read_csv('y_val.csv')

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5655       1              1        0           0  0.126761             1
# 101        1              0        1           1  0.000000             1
# 2616       0              0        1           0  0.985915             1
# 392        1              1        0           0  0.014085             1
# 1323       0              0        1           0  0.816901             1
# ...      ...            ...      ...         ...       ...           ...
# 3046       1              0        1           1  0.985915             1
# 1725       0              0        0           0  0.000000             1
# 4079       1              0        1           0  1.000000             1
# 2254       1              0        0           0  0.098592             1
# 2915       1              0        1           0  1.000000             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5655              0               0             0                 1  ...
# 101               0               0             0                 0  ...
# 2616              0               0             1                 1  ...
# 392               0               0             0                 0  ...
# 1323              1               0             0                 1  ...
# ...             ...             ...           ...               ...  ...
# 3046              1               1             1                 1  ...
# 1725              1               0             0                 0  ...
# 4079              1               1             1                 1  ...
# 2254              0               0             0                 0  ...
# 2915              0               1             1                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5655                    0                            1                   0
# 101                     0                            0                   1
# 2616                    1                            0                   0
# 392                     1                            0                   0
# 1323                    0                            1                   0
# ...                   ...                          ...                 ...
# 3046                    1                            0                   0
# 1725                    1                            0                   0
# 4079                    1                            0                   0
# 2254                    0                            0                   1
# 2915                    1                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5655                        1                  0                  0
# 101                         1                  0                  0
# 2616                        0                  0                  1
# 392                         1                  0                  0
# 1323                        0                  1                  0
# ...                       ...                ...                ...
# 3046                        0                  0                  1
# 1725                        1                  0                  0
# 4079                        0                  0                  1
# 2254                        0                  0                  1
# 2915                        0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5655                                        0
# 101                                         0
# 2616                                        0
# 392                                         0
# 1323                                        1
# ...                                       ...
# 3046                                        1
# 1725                                        0
# 4079                                        0
# 2254                                        0
# 2915                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5655                                      1                               0
# 101                                       0                               1
# 2616                                      1                               0
# 392                                       0                               1
# 1323                                      0                               0
# ...                                     ...                             ...
# 3046                                      0                               0
# 1725                                      0                               1
# 4079                                      1                               0
# 2254                                      0                               0
# 2915                                      0                               0
#
#       PaymentMethod_Mailed check
# 5655                           0
# 101                            0
# 2616                           0
# 392                            0
# 1323                           0
# ...                          ...
# 3046                           0
# 1725                           0
# 4079                           0
# 2254                           1
# 2915                           1
#
# [5625 rows x 26 columns]

# %%
# feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
type(y_test)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.DataFrame(X_test).to_csv('X_test_val.csv', index=False)

# %% [markdown]
# ### 2. Model creation

# %%
type(y_train)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.model_selection import RandomizedSearchCV

params = {
        'min_child_weight': [1, 5],
        'max_depth': [1, 3]
        }

model = XGBClassifier()

random_search = RandomizedSearchCV(model, param_distributions=params, 
                                   scoring='accuracy', 
                                   verbose=3, cv=3)
random_search.fit(X_train, y_train.values)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [14:44:01] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/3] END ...max_depth=1, min_child_weight=1;, score=0.809 total time=   0.3s
# [14:44:01] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/3] END ...max_depth=1, min_child_weight=1;, score=0.810 total time=   0.3s
# [14:44:01] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/3] END ...max_depth=1, min_child_weight=1;, score=0.805 total time=   0.3s
# [14:44:02] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/3] END ...max_depth=1, min_child_weight=5;, score=0.808 total time=   0.3s
# [14:44:02] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/3] END ...max_depth=1, min_child_weight=5;, score=0.809 total time=   0.3s
# [14:44:02] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/3] END ...max_depth=1, min_child_weight=5;, score=0.805 total time=   0.3s
# [14:44:03] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/3] END ...max_depth=3, min_child_weight=1;, score=0.795 total time=   0.4s
# [14:44:03] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/3] END ...max_depth=3, min_child_weight=1;, score=0.799 total time=   0.4s
# [14:44:03] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/3] END ...max_depth=3, min_child_weight=1;, score=0.798 total time=   0.4s
# [14:44:04] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/3] END ...max_depth=3, min_child_weight=5;, score=0.796 total time=   0.4s
# [14:44:04] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/3] END ...max_depth=3, min_child_weight=5;, score=0.798 total time=   0.4s
# [14:44:04] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/3] END ...max_depth=3, min_child_weight=5;, score=0.805 total time=   0.4s
# [14:44:05] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            enable_categorical=False, gamma=None,
#                                            gpu_id=None, importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate=None,
#                                            max_delta_step=None, max_depth=None,
#                                            min_child_weight=None, missing=nan,
#                                            monotone_constraints=None,
#                                            n_estimators=100, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            predictor=None, random_state=None,
#                                            reg_alpha=None, reg_lambda=None,
#                                            scale_pos_weight=None,
#                                            subsample=None, tree_method=None,
#                                            validate_parameters=None,
#                                            verbosity=None),
#                    param_distributions={'max_depth': [1, 3],
#                                         'min_child_weight': [1, 5]},
#                    scoring='accuracy', verbose=3)

# %% [markdown]
# ### 3. Model training and validation

# %% [markdown]
# ### Save model binary

# %%
random_search.best_estimator_.save_model('model_xg_hyper_test.json')
