# %%
# !hostname
# Out:
# notebook-server-danish-xgboost-e-2-e-863e750-0

# %%
import requests
import json

# %%
# curl --header 'Content-Type: application/json' --header 'apikey: REPLACE-WITH-YOUR-API-KEY' --data '{}' --request POST 'https://qa-models.a360.ai/danish-test-churn-pred-demo-xgboost-e2e-1/'

# %%
url = "https://qa-models.a360.ai/danish-test-churn-pred-demo-xgboost-e2e-1/"
headers = {'Content-Type': "application/json",
          'apikey': "84268613-9eea-4cb9-9eb8-249173e823c9"}

# %%
data = {'gender': 1.000000,
'SeniorCitizen': 0.000000,
'Partner': 1.000000,
'Dependents': 0.000000,
'tenure': 0.000000,
'PhoneService': 0.000000,
'MultipleLines': 0.000000,
'OnlineSecurity': 0.000000,
'OnlineBackup': 1.000000,
'DeviceProtection': 0.000000,
'TechSupport': 0.000000,
'StreamingTV': 0.000000,
'StreamingMovies': 0.000000,
'PaperlessBilling': 1.000000,
'MonthlyCharges': 0.115423, 
'TotalCharges': 0.001275,
'InternetService_DSL': 1.000000, 
'InternetService_Fiber optic': 0.000000,
'InternetService_No': 0.000000, 
'Contract_Month-to-month': 1.000000, 
'Contract_One year': 0.000000,
'Contract_Two year': 0.000000, 
'PaymentMethod_Bank transfer (automatic)': 0.000000,
'PaymentMethod_Credit card (automatic)': 0.000000, 
'PaymentMethod_Electronic check': 1.000000, 
'PaymentMethod_Mailed check': 0.000000}

# %%
data = json.dumps(data,indent=2)

# %%
prediction = requests.post(url,data=data,headers=headers).text.split(':')[-1].split("}")[0]
prediction
# Out:
# '0.0'
